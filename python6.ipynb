# %% [markdown]
# <a href="https://colab.research.google.com/github/goyalnishtha841/cognitive-computing-/blob/main/python6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
M=int(input('enter a value'))
x=np.linspace(-10,10,M)
# Out:
# enter a value10

# %%
y1=M* x**2
y2=M* np.sin(x)

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, y1, 'b-', label=f'y = {M}x²')
plt.plot(x, y2, 'r--', label=f'y = {M}sin(x)')
plt.legend()
plt.grid(True)
plt.title("Plot of y = Mx² and y = Msin(x)")
plt.xlabel("x values")
plt.ylabel("y values")

plt.show()

# %%
data = {'Subject': ['Math', 'Science', 'English', 'History', 'Computer'],
        'Score': [85, 92, 78, 88, 95]}


df =pd.DataFrame(data)


plt.figure(figsize=(8, 5))
ax = sns.barplot(x='Subject', y='Score', data=df, palette='viridis')


for p in ax.patches:
    ax.annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=12, fontweight='bold', color='black')

plt.title("Student Scores by Subject", fontsize=14)
plt.xlabel("Subjects", fontsize=12)
plt.ylabel("Scores", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)


plt.show()
# Out:
# <ipython-input-5-ea84f764fb2c>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Subject', y='Score', data=df, palette='viridis')

# %%
roll_number = 102317133
np.random.seed(roll_number)


data = np.random.randn(50)


fig, axes = plt.subplots(2, 2, figsize=(10, 8))

axes[0, 0].plot(np.cumsum(data), marker='o', linestyle='-', color='b')
axes[0, 0].set_title("Cumulative Sum Line Plot")
axes[0, 0].set_xlabel("Index")
axes[0, 0].set_ylabel("Cumulative Sum")
axes[0, 0].grid(True)

axes[0, 1].scatter(range(50), data + np.random.normal(0, 0.2, 50), color='r', alpha=0.7)
axes[0, 1].set_title("Scatter Plot with Noise")
axes[0, 1].set_xlabel("Index")
axes[0, 1].set_ylabel("Value")
axes[0, 1].grid(True)


axes[1, 0].axis('off')
axes[1, 1].axis('off')


plt.tight_layout()
plt.show()

# %%
url = 'https://raw.githubusercontent.com/AnjulaMehto/MCA/main/company_sales_data.csv'
data = pd.read_csv(url)

print(data.head())


plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='month_number', y='total_profit', marker='o', color='b')
plt.title('Total Profit per Month')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 8))
product_columns = ['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer']
for product in product_columns:
    sns.lineplot(data=data, x='month_number', y=product, marker='o', label=product)
plt.title('Product Sales Data')
plt.xlabel('Month Number')
plt.ylabel('Sales Units')
plt.legend(title='Products')
plt.grid(True)
plt.show()


melted_data = data.melt(id_vars='month_number', var_name='Feature', value_name='Value')
plt.figure(figsize=(14, 10))
sns.barplot(data=melted_data, x='month_number', y='Value', hue='Feature')
plt.title('Bar Chart of All Features/Attributes')
plt.xlabel('Month Number')
plt.ylabel('Value')
plt.legend(title='Features', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600
